# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
from GraphLaplacian.binary import GraphLaplacian, MBOBinary
from GraphLaplacian.helper import plot
import pdb
from IPython.display import clear_output
from sklearn.datasets import make_moons, make_circles, make_classification
import scipy
import pdb

sns.set()

# %% [markdown]
# ## Case 1

# %%
N = 1000
L = 80

X0 = [[0, 4*i/(L/4)] for i in range(np.int32(L/4))]
X0 += [[2*i/(L/8), 0] for i in range(np.int32(L/8))]
X0 += [[2*i/(L/8), 4] for i in range(np.int32(L/8))]

X0 += [[4, 4*i/(L/4)] for i in range(np.int32(L/4))]
X0 += [[2 + 2*i/(L/8), 0] for i in range(np.int32(L/8))]
X0 += [[2 + 2*i/(L/8), 4] for i in range(np.int32(L/8))]

Y0 = [0 for i in range(np.int32(L/2))]
Y0 += [1 for i in range(np.int32(L/2))]
Y0 = np.array(Y0)

## Generate X Data
X1 = [[random.random()*4, random.random()*4] for i in range(np.int32(N))]

plot(X0, Y0, X1)

# %%
GL = GraphLaplacian(X0, Y0, X1, cov=1)
GL.solve()
plot(X0 + X1, GL.Y, [])

# %%
MBO = MBOBinary(X0, Y0, X1, cov=1, dT=0.01, Nd=3)
MBO.solve()
plot(X0 + X1, MBO.Y, [])
# Out:
# Interation 0 error 0.4892367906066536
# Interation 1 error 0.0

# %% [markdown]
# ## Case 2

# %%
X, Y = make_moons(noise=0.1, random_state=0, n_samples=1000)
X0 = list([X[i] for i,y in enumerate(Y) if y==0][:40] + [X[i] for i,y in enumerate(Y) if y==1][:40])
Y0 = list([y for y in Y if y==0][:40] + [y for y in Y if y==1][:40])
X1 = list(X[120:])
plot(X0,Y0,X1)

# %%
GL = GraphLaplacian(X0, Y0, X1, cov=0.3)
GL.solve()
plot(X0 + X1, GL.Y, [])

# %%
MBO = MBOBinary(X0, Y0, X1, cov=0.3, dT=0.01, Nd=3)
MBO.solve()
plot(X0 + X1, MBO.Y, [])
# Out:
# Interation 0 error 0.4988662131519274
# Interation 1 error 0.0

# %% [markdown]
# ## Case 3

# %%
N = 120
X, Y = make_circles(noise=0.11, factor=0.5, random_state=1, n_samples=1000)
X0 = list([X[i] for i,y in enumerate(Y) if y==0][:80] + [X[i] for i,y in enumerate(Y) if y==1][:80])
Y0 = list([y for y in Y if y==0][:80] + [y for y in Y if y==1][:80])
X1 = list(X[160:])
plot(X0,Y0,X1)

# %%
GL = GraphLaplacian(X0, Y0, X1, cov=0.3)
GL.solve()
plot(X0 + X1, GL.Y, [])

# %%
MBO = MBOBinary(X0, Y0, X1, cov=0.3, dT=0.01, Nd=3)
MBO.solve()
plot(X0 + X1, MBO.Y, [])
# Out:
# Interation 0 error 0.40076335877862596
# Interation 1 error 0.0

# %%
MBO = MBOBinary(X0, Y0, X1, cov=0.3, dT=0.001, Nd=3)
MBO.solve()
plot(X0 + X1, MBO.Y, [])
# Out:
# Interation 0 error 0.46153846153846156
# Interation 1 error 0.0

# %%
MBO = MBOBinary(X0, Y0, X1, cov=0.3, dT=0.0001, Nd=3)
MBO.solve()
plot(X0 + X1, MBO.Y, [])
# Out:
# Interation 0 error 0.4666666666666667
# Interation 1 error 0.0

# %%
MBO = MBOBinary(X0, Y0, X1, cov=0.3, dT=0.1, Nd=3)
MBO.solve()
plot(X0 + X1, MBO.Y, [])
# Out:
# Interation 0 error 0.29535864978902954
# Interation 1 error 0.0754226267880364
# Interation 2 error 0.02781289506953224
# Interation 3 error 0.010012515644555695
# Interation 4 error 0.0024968789013732834
# Interation 5 error 0.0
