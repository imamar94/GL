# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
from GraphLaplacian.binary import GraphLaplacian, MBOBinary
from GraphLaplacian.multilabel import GLMultiClass, MBOMultiClass
from GraphLaplacian.helper import plot
import pdb
from IPython.display import clear_output
from sklearn.datasets import make_moons, make_circles, make_classification, make_blobs
import scipy
import pdb

sns.set()

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

def create_score_sheet(method, y_true, y_pred):
    return {"Method":method, 
            "accuracy":accuracy_score(y_true, y_pred), 
            "f1_score": f1_score(y_true, y_pred), 
            "presicion": precision_score(y_true, y_pred), 
            "recall": recall_score(y_true, y_pred)}

# %% [markdown]
# ## Data 1

# %% [markdown]
# ## Balanced Class

# %%
X0 = list(blue[:30]) + list(red[:30])
Y0 = list(np.ones(len(blue)))[:30] + list(np.ones(len(red))*0)[:30]
X1 = list(blue[30:]) + list(red[30:])

plot(X0, Y0, X1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-77fc3e1d5a2b> in <module>
# ----> 1 X0 = list(blue[:30]) + list(red[:30])
#       2 Y0 = list(np.ones(len(blue)))[:30] + list(np.ones(len(red))*0)[:30]
#       3 X1 = list(blue[30:]) + list(red[30:])
#       4
#       5 plot(X0, Y0, X1)
#
# NameError: name 'blue' is not defined

# %%
GL = GraphLaplacian(X0, Y0, X1, cov=1)
GL.solve()
plot(X0 + X1, GL.Y, [])

# %%
MBO = MBOBinary(X0, Y0, X1, cov=1sfasdf, dT=0.001, Nd=3)
MBO.solve()
plot(X0 + X1, MBO.Y, [])
# Out:
# Interation 0 error 0.5199115044247787
# Interation 1 error 0.0

# %% [markdown]
# ## Unbalanced Class

# %%
X0 = list(blue[:40]) + list(red[:20])
Y0 = list(np.ones(len(blue)))[:40] + list(np.ones(len(red))*0)[:20]
X1 = list(blue[40:]) + list(red[20:])

plot(X0, Y0, X1)

# %%
GL = GraphLaplacian(X0, Y0, X1, cov=1)
GL.solve()
plot(X0 + X1, GL.Y, [])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-e1f2299019bd> in <module>
#       1 GL = GraphLaplacian(X0, Y0, X1, cov=1)
# ----> 2 GL.solve()
#       3 plot(X0 + X1, GL.Y, [])
#
# ~/OneDrive/Documents/repository/GL/GraphLaplacian/binary.py in solve(self, method, ret, feature_important)
#      77
#      78     def solve(self, method="cg", ret=False, feature_important=[]):
# ---> 79         A, b = self.create_linear_system(feature_important)
#      80         if method == "cg":
#      81             U = scipy.sparse.linalg.cg(A, b)[0]
#
# ~/OneDrive/Documents/repository/GL/GraphLaplacian/binary.py in create_linear_system(self, feature_important)
#      60                 w = [f.pdf([X[j]]) if i != j else 0 for j in range(len(X))]
#      61                 return w
# ---> 62             W = np.array(list(map(process_xi, enumerate(X))))
#      63             # print("w shape", W.shape)
#      64             # print("Creating weight matrix cost", datetime.now() - tic2)
#
# ~/OneDrive/Documents/repository/GL/GraphLaplacian/binary.py in process_xi(xi)
#      58                 xi = xi[1]
#      59                 f = multivariate_normal(mean=xi, cov=cov)
# ---> 60                 w = [f.pdf([X[j]]) if i != j else 0 for j in range(len(X))]
#      61                 return w
#      62             W = np.array(list(map(process_xi, enumerate(X))))
#
# ~/OneDrive/Documents/repository/GL/GraphLaplacian/binary.py in <listcomp>(.0)
#      58                 xi = xi[1]
#      59                 f = multivariate_normal(mean=xi, cov=cov)
# ---> 60                 w = [f.pdf([X[j]]) if i != j else 0 for j in range(len(X))]
#      61                 return w
#      62             W = np.array(list(map(process_xi, enumerate(X))))
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/stats/_multivariate.py in pdf(self, x)
#     748
#     749     def pdf(self, x):
# --> 750         return np.exp(self.logpdf(x))
#     751
#     752     def logcdf(self, x):
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/stats/_multivariate.py in logpdf(self, x)
#     744         x = self._dist._process_quantiles(x, self.dim)
#     745         out = self._dist._logpdf(x, self.mean, self.cov_info.U,
# --> 746                                  self.cov_info.log_pdet, self.cov_info.rank)
#     747         return _squeeze_output(out)
#     748
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/stats/_multivariate.py in _logpdf(self, x, mean, prec_U, log_det_cov, rank)
#     468         """
#     469         dev = x - mean
# --> 470         maha = np.sum(np.square(np.dot(dev, prec_U)), axis=-1)
#     471         return -0.5 * (rank * _LOG_2PI + log_det_cov + maha)
#     472
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2180
#    2181     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2182                           initial=initial, where=where)
#    2183
#    2184
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      71
#      72
# ---> 73 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#      74     passkwargs = {k: v for k, v in kwargs.items()
#      75                   if v is not np._NoValue}
#
# KeyboardInterrupt:

# %%
MBO = MBOBinary(X0, Y0, X1, cov=5, dT=0.001, Nd=3)
MBO.solve()
plot(X0 + X1, MBO.Y, [])
# Out:
# Interation 0 error 0.44594594594594594
# Interation 1 error 0.0

# %%
N = 10
X0 = list(blue[:N]) + list(red[:N])
Y0 = list(np.ones(len(blue)))[:N] + list(np.ones(len(red))*0)[:N]
X1 = list(blue[N:]) + list(red[N:])
Y1 = list(np.ones(len(blue)))[N:] + list(np.ones(len(red))*0)[N:]

plot(X0, Y0, X1)

# %%
print("N Blue :", N, "N Red :", N)
print("Graph Laplacian")
GL = GraphLaplacian(X0, Y0, X1, cov=5)
GL.solve()
display(plot(X0 + X1, GL.Y, []))
# Out:
# N Blue : 5 N Red : 5
# Graph Laplacian
# None

# %%
print("N Blue :", N, "N Red :", N)
print("MBO")
MBO = MBOBinary(X0, Y0, X1, cov=5, dT=0.01)
MBO.solve()
display(plot(X0 + X1, MBO.Y, []))
# Out:
# N Blue : 5 N Red : 5
# MBO
# Interation 0 error 0.476878612716763
# Interation 1 error 0.0
# None

# %%
print("N Blue :", N, "N Red :", N)
print("MBO")
MBO = MBOBinary(X0, Y0, X1, cov=0.5, dT=0.01)
MBO.solve()
display(plot(X0 + X1, MBO.Y, []))
# Out:
# N Blue : 5 N Red : 5
# MBO
# Interation 0 error 0.64453125
# Interation 1 error 0.0
# None

# %%
print("N Blue :", N, "N Red :", N)
print("MBO")
MBO = MBOBinary(X0, Y0, X1, cov=0.5, dT=0.1)
MBO.solve()
display(plot(X0 + X1, MBO.Y, []))
# Out:
# N Blue : 5 N Red : 5
# MBO
# Interation 0 error 0.55
# Interation 1 error 0.0
# None

# %%
print("N Blue :", N, "N Red :", N)
print("MBO")
MBO = MBOBinary(X0, Y0, X1, cov=0.5, dT=0.1, Nd=50)
MBO.solve()
display(plot(X0 + X1, MBO.Y, []))
# Out:
# N Blue : 5 N Red : 5
# MBO
# Interation 0 error 0.64453125
# Interation 1 error 0.0
# None

# %%
print("N Blue :", N, "N Red :", N)
print("MBO")
MBO = MBOBinary(X0, Y0, X1, cov=0.5, dT=50, Nd=1)
MBO.solve()
display(plot(X0 + X1, MBO.Y, []))
# Out:
# N Blue : 5 N Red : 5
# MBO
# Interation 0 error 0.4891304347826087
# Interation 1 error 0.003968253968253968
# Interation 2 error 0.0
# None

# %%
print("N Blue :", N, "N Red :", N)
print("MBO")
MBO = MBOBinary(X0, Y0, X1, cov=0.5, dT=5, Nd=50)
MBO.solve()
display(plot(X0 + X1, MBO.Y, []))
# Out:
# N Blue : 5 N Red : 5
# MBO
# Interation 0 error 0.49302788844621515
# Interation 1 error 0.01006036217303823
# Interation 2 error 0.0
# None

# %%
create_score_sheet("MBO",  Y1, MBO.Y[len(X0):])
# Out:
# {'Method': 'MBO',
#  'accuracy': 0.897979797979798,
#  'f1_score': 0.8896174863387978,
#  'presicion': 0.969047619047619,
#  'recall': 0.8222222222222222}

# %%
print("N Blue :", N, "N Red :", N)
print("Graph Laplacian")
GL = GraphLaplacian(X0, Y0, X1, cov=0.5)
GL.solve()
display(plot(X0 + X1, GL.Y, []))
# Out:
# N Blue : 5 N Red : 5
# Graph Laplacian
# None

# %%
create_score_sheet("GL",  Y1, GL.Y[len(X0):])
# Out:
# {'Method': 'GL',
#  'accuracy': 0.9585858585858585,
#  'f1_score': 0.9590409590409591,
#  'presicion': 0.9486166007905138,
#  'recall': 0.9696969696969697}

# %%
result = list()
for N in [5, 10, 20, 40, 80, 160]:
    X0 = list(blue[:N]) + list(red[:N])
    Y0 = list(np.ones(len(blue)))[:N] + list(np.ones(len(red))*0)[:N]
    X1 = list(blue[N:]) + list(red[N:])
    Y1 = list(np.ones(len(blue)))[N:] + list(np.ones(len(red))*0)[N:]
    
    print("N Blue :", N, "N Red :", N)
    print("Graph Laplacian")
    GL = GraphLaplacian(X0, Y0, X1, cov=0.5)
    GL.solve()
    display(plot(X0 + X1, GL.Y, []))
    
    print("MBO")
    MBO = MBOBinary(X0, Y0, X1, cov=0.5, dT=0.001, Nd=3)
    MBO.solve()
    display(plot(X0 + X1, MBO.Y, []))
    print("=================================")
    score_gl = create_score_sheet("Graph Laplacian", Y1, GL.Y[len(X0):])
    score_gl["N"] = N
    score_mbo = create_score_sheet("MBO", Y1, MBO.Y[len(X0):])
    score_mbo["N"] = N
    result += [
        score_gl,
        score_mbo
    ]
# Out:
# N Blue : 5 N Red : 5
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.5574324324324325
# Interation 1 error 0.0
# None
# =================================
# N Blue : 10 N Red : 10
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.5147058823529411
# Interation 1 error 0.0
# None
# =================================
# N Blue : 20 N Red : 20
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.5183585313174947
# Interation 1 error 0.0
# None
# =================================
# N Blue : 40 N Red : 40
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.5203619909502263
# Interation 1 error 0.0
# None
# =================================
# N Blue : 80 N Red : 80
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.5084745762711864
# Interation 1 error 0.0
# None
# =================================
# N Blue : 160 N Red : 160
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.5167173252279635
# Interation 1 error 0.0
# None
# =================================

# %%
df = pd.DataFrame(result)
df.to_csv("output/2_Imbalanced N 1000.csv", encoding="utf-8", index=False)
df
# Out:
#              Method  accuracy  f1_score  presicion    recall    N
# 0   Graph Laplacian  0.959596  0.959920   0.952286  0.967677    5
# 1               MBO  0.863636  0.856230   0.905405  0.812121    5
# 2   Graph Laplacian  0.961224  0.961303   0.959350  0.963265   10
# 3               MBO  0.916327  0.915114   0.928571  0.902041   10
# 4   Graph Laplacian  0.964583  0.964876   0.956967  0.972917   20
# 5               MBO  0.903125  0.901379   0.917927  0.885417   20
# 6   Graph Laplacian  0.961957  0.961665   0.969095  0.954348   40
# 7               MBO  0.934783  0.933481   0.952489  0.915217   40
# 8   Graph Laplacian  0.963095  0.962785   0.970944  0.954762   80
# 9               MBO  0.955952  0.955582   0.963680  0.947619   80
# 10  Graph Laplacian  0.958824  0.957958   0.978528  0.938235  160
# 11              MBO  0.960294  0.959641   0.975684  0.944118  160

# %%
df = pd.read_csv("output/2_Imbalanced N 1000.csv")
for c in df.iloc[:, 1:5].columns:
    df.loc[:, c] = df[c].apply(lambda x: "{}%".format(round(x*100, 2)))
df.rename(columns={"N":"N0"}, inplace=True)
pd.pivot_table(df, values=["accuracy", "f1_score", "presicion", "recall"], index=["N0"],
                    columns=['Method'], aggfunc=np.sum)
# Out:
#               accuracy                f1_score               presicion  \
# Method Graph Laplacian     MBO Graph Laplacian     MBO Graph Laplacian
# N0
# 5               95.96%  86.36%          95.99%  85.62%          95.23%
# 10              96.12%  91.63%          96.13%  91.51%          95.93%
# 20              96.46%  90.31%          96.49%  90.14%           95.7%
# 40               96.2%  93.48%          96.17%  93.35%          96.91%
# 80              96.31%   95.6%          96.28%  95.56%          97.09%
# 160             95.88%  96.03%           95.8%  95.96%          97.85%
#
#                         recall
# Method     MBO Graph Laplacian     MBO
# N0
# 5       90.54%          96.77%  81.21%
# 10      92.86%          96.33%   90.2%
# 20      91.79%          97.29%  88.54%
# 40      95.25%          95.43%  91.52%
# 80      96.37%          95.48%  94.76%
# 160     97.57%          93.82%  94.41%

# %%
colors = ["#ff6361", "#003f5c", "#63005c", "#006355", "#5c3f00"]
sns.set_palette(sns.color_palette(colors))
df = pd.read_csv("output/2_Imbalanced N 1000.csv")
for c in df.iloc[:, 1:5].columns:
    df.loc[:, c] = df[c].apply(lambda x: round(x,2))
df.rename(columns={"N":"N0"}, inplace=True)
sns.lineplot(data=df, x="N0", y="accuracy", hue="Method")

# %%
colors = ["#ff6361", "#003f5c", "#63005c", "#006355", "#5c3f00"]
sns.set_palette(sns.color_palette(colors))
df = pd.read_csv("output/2_Imbalanced N 1000.csv")
for c in df.iloc[:, 1:5].columns:
    df.loc[:, c] = df[c].apply(lambda x: round(x,2))
df.rename(columns={"N":"N0"}, inplace=True)
sns.lineplot(data=df, x="N0", y="f1_score", hue="Method")

# %% [markdown]
# ## Different Density

# %% [markdown]
# ### 3:7

# %%
cov1 = np.array([[6,0],[0,2]])
blue = np.random.multivariate_normal(mean=[0,2], cov=cov1, size=300)
cov2 = np.array([[6,0],[0,2]])
red = np.random.multivariate_normal(mean=[0,-3], cov=cov2, size=700)
Y = list(np.ones(len(blue))) + list(np.ones(len(red))*0)
X = list(blue) + list(red)

plot(X, Y, [])

# %%
X0 = list(blue[:30]) + list(red[:30])
Y0 = list(np.ones(len(blue)))[:30] + list(np.ones(len(red))*0)[:30]
X1 = list(blue[30:]) + list(red[30:])

plot(X0, Y0, X1)

# %%
GL = GraphLaplacian(X0, Y0, X1, cov=1)
GL.solve()
plot(X0 + X1, GL.Y, [])

# %%
MBO = MBOBinary(X0, Y0, X1, cov=1, dT=0.001, Nd=3)
MBO.solve()
plot(X0 + X1, MBO.Y, [])
# Out:
# Interation 0 error 0.8422939068100358
# Interation 1 error 0.0

# %%
result = list()
for N in [5, 10, 20, 40, 80, 160]:
    X0 = list(blue[:N]) + list(red[:N])
    Y0 = list(np.ones(len(blue)))[:N] + list(np.ones(len(red))*0)[:N]
    X1 = list(blue[N:]) + list(red[N:])
    Y1 = list(np.ones(len(blue)))[N:] + list(np.ones(len(red))*0)[N:]
    
    print("N Blue :", N, "N Red :", N)
    print("Graph Laplacian")
    GL = GraphLaplacian(X0, Y0, X1, cov=0.5)
    GL.solve()
    display(plot(X0 + X1, GL.Y, []))
    
    print("MBO")
    MBO = MBOBinary(X0, Y0, X1, cov=0.5, dT=0.001, Nd=3)
    MBO.solve()
    display(plot(X0 + X1, MBO.Y, []))
    print("=================================")
    score_gl = create_score_sheet("Graph Laplacian", Y1, GL.Y[len(X0):])
    score_gl["N"] = N
    score_mbo = create_score_sheet("MBO", Y1, MBO.Y[len(X0):])
    score_mbo["N"] = N
    result += [
        score_gl,
        score_mbo
    ]
# Out:
# N Blue : 5 N Red : 5
# Graph Laplacian
# None
# MBO
# Interation 0 error 1.0399159663865547
# Interation 1 error 0.0
# None
# =================================
# N Blue : 10 N Red : 10
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.9496124031007752
# Interation 1 error 0.0
# None
# =================================
# N Blue : 20 N Red : 20
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.8727272727272727
# Interation 1 error 0.0
# None
# =================================
# N Blue : 40 N Red : 40
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.8846153846153846
# Interation 1 error 0.0
# None
# =================================
# N Blue : 80 N Red : 80
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.9090909090909091
# Interation 1 error 0.0
# None
# =================================
# N Blue : 160 N Red : 160
# Graph Laplacian
# None
# MBO
# Interation 0 error 1.1333333333333333
# Interation 1 error 0.0
# None
# =================================

# %%
df = pd.DataFrame(result)
df.to_csv("output/2_Balanced initial_imbalance result 7_3.csv", encoding="utf-8", index=False)
df
# Out:
#              Method  accuracy  f1_score  presicion    recall    N
# 0   Graph Laplacian  0.951515  0.911439   1.000000  0.837288    5
# 1               MBO  0.924242  0.859287   0.962185  0.776271    5
# 2   Graph Laplacian  0.966327  0.940109   0.992337  0.893103   10
# 3               MBO  0.934694  0.883212   0.937984  0.834483   10
# 4   Graph Laplacian  0.972917  0.952381   0.977444  0.928571   20
# 5               MBO  0.953125  0.918919   0.927273  0.910714   20
# 6   Graph Laplacian  0.970652  0.946955   0.967871  0.926923   40
# 7               MBO  0.965217  0.938462   0.938462  0.938462   40
# 8   Graph Laplacian  0.973810  0.949309   0.962617  0.936364   80
# 9               MBO  0.965476  0.935698   0.913420  0.959091   80
# 10  Graph Laplacian  0.976471  0.943262   0.936620  0.950000  160
# 11              MBO  0.970588  0.931034   0.900000  0.964286  160

# %%
df = pd.read_csv("output/2_Balanced initial_imbalance result 7_3.csv")
for c in df.iloc[:, 1:5].columns:
    df.loc[:, c] = df[c].apply(lambda x: "{}%".format(round(x*100, 2)))
df.rename(columns={"N":"N0"}, inplace=True)
display(pd.pivot_table(df, values=["accuracy", "f1_score", "presicion", "recall"], index=["N0"],
                    columns=['Method'], aggfunc=np.sum))

colors = ["#ff6361", "#003f5c", "#63005c", "#006355", "#5c3f00"]
sns.set_palette(sns.color_palette(colors))
df = pd.read_csv("output/2_Balanced initial_imbalance result 7_3.csv")
for c in df.iloc[:, 1:5].columns:
    df.loc[:, c] = df[c].apply(lambda x: round(x,2))
df.rename(columns={"N":"N0"}, inplace=True)
display(sns.lineplot(data=df, x="N0", y="accuracy", hue="Method"))
# Out:
#               accuracy                f1_score               presicion  \
# Method Graph Laplacian     MBO Graph Laplacian     MBO Graph Laplacian
# N0
# 5               95.15%  92.42%          91.14%  85.93%          100.0%
# 10              96.63%  93.47%          94.01%  88.32%          99.23%
# 20              97.29%  95.31%          95.24%  91.89%          97.74%
# 40              97.07%  96.52%           94.7%  93.85%          96.79%
# 80              97.38%  96.55%          94.93%  93.57%          96.26%
# 160             97.65%  97.06%          94.33%   93.1%          93.66%
#
#                         recall
# Method     MBO Graph Laplacian     MBO
# N0
# 5       96.22%          83.73%  77.63%
# 10       93.8%          89.31%  83.45%
# 20      92.73%          92.86%  91.07%
# 40      93.85%          92.69%  93.85%
# 80      91.34%          93.64%  95.91%
# 160      90.0%           95.0%  96.43%

# %%
colors = ["#ff6361", "#003f5c", "#63005c", "#006355", "#5c3f00"]
sns.set_palette(sns.color_palette(colors))
df = pd.read_csv("output/2_Balanced initial_imbalance result 7_3.csv")
for c in df.iloc[:, 1:5].columns:
    df.loc[:, c] = df[c].apply(lambda x: round(x,2))
df.rename(columns={"N":"N0"}, inplace=True)
display(sns.lineplot(data=df, x="N0", y="f1_score", hue="Method"))

# %%
result = list()
for N in [5, 10, 20, 40, 80, 160]:
    X0 = list(blue[:N]) + list(red[:2*N])
    Y0 = list(np.ones(len(blue)))[:N] + list(np.ones(len(red))*0)[:2*N]
    X1 = list(blue[N:]) + list(red[2*N:])
    Y1 = list(np.ones(len(blue)))[N:] + list(np.ones(len(red))*0)[2*N:]
    
    print("N Blue :", N, "N Red :", 2*N)
    print("Graph Laplacian")
    GL = GraphLaplacian(X0, Y0, X1, cov=0.5)
    GL.solve()
    display(plot(X0 + X1, GL.Y, []))
    
    print("MBO")
    MBO = MBOBinary(X0, Y0, X1, cov=0.5, dT=0.001, Nd=3)
    MBO.solve()
    display(plot(X0 + X1, MBO.Y, []))
    print("=================================")
    score_gl = create_score_sheet("Graph Laplacian", Y1, GL.Y[len(X0):])
    score_gl["N"] = N
    score_mbo = create_score_sheet("MBO", Y1, MBO.Y[len(X0):])
    score_mbo["N"] = N
    result += [
        score_gl,
        score_mbo
    ]
# Out:
# N Blue : 5 N Red : 10
# Graph Laplacian
# None
# MBO
# Interation 0 error 1.1400462962962963
# Interation 1 error 0.0
# None
# =================================
# N Blue : 10 N Red : 20
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.9817813765182186
# Interation 1 error 0.0
# None
# =================================
# N Blue : 20 N Red : 40
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.9215686274509803
# Interation 1 error 0.0
# None
# =================================
# N Blue : 40 N Red : 80
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.9016393442622951
# Interation 1 error 0.0
# None
# =================================
# N Blue : 80 N Red : 160
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.9178743961352657
# Interation 1 error 0.0
# None
# =================================
# N Blue : 160 N Red : 320
# Graph Laplacian
# None
# MBO
# Interation 0 error 0.9923664122137404
# Interation 1 error 0.0
# None
# =================================

# %%
df = pd.DataFrame(result)
df.to_csv("output/2_imbalanced initial_imbalance result 7_3.csv", encoding="utf-8", index=False)
df
# Out:
#              Method  accuracy  f1_score  presicion    recall    N
# 0   Graph Laplacian  0.939086  0.886792   1.000000  0.796610    5
# 1               MBO  0.905584  0.818004   0.967593  0.708475    5
# 2   Graph Laplacian  0.965979  0.939891   0.996139  0.889655   10
# 3               MBO  0.928866  0.871508   0.947368  0.806897   10
# 4   Graph Laplacian  0.969149  0.945794   0.992157  0.903571   20
# 5               MBO  0.952128  0.915888   0.960784  0.875000   20
# 6   Graph Laplacian  0.971591  0.949900   0.991632  0.911538   40
# 7               MBO  0.961364  0.932540   0.963115  0.903846   40
# 8   Graph Laplacian  0.975000  0.955294   0.990244  0.922727   80
# 9               MBO  0.967105  0.941452   0.971014  0.913636   80
# 10  Graph Laplacian  0.976923  0.955556   0.992308  0.921429  160
# 11              MBO  0.975000  0.952030   0.984733  0.921429  160
